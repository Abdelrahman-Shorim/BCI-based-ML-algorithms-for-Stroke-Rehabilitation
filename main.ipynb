# %%
import mne
import preprocessing

# %%
dataset_directory = './dataset/'
subject_files = [f'A0{i}T.gdf' for i in range(1, 10)]
raws = []

for file in subject_files:
    file_path = dataset_directory + file
    raw = mne.io.read_raw_gdf(file_path, preload=True, stim_channel='auto')
    raws.append(raw)
raw_combined = mne.concatenate_raws(raws)
channel_names_mapping = {
    'EEG-0': 'FC3',
    'EEG-1': 'FC1',
    'EEG-2': 'FCz',
    'EEG-3': 'FC2',
    'EEG-4': 'FC4',
    'EEG-5': 'C5',
    'EEG-6': 'C1',
    'EEG-7': 'C2',  # Often corresponds to T7 in the extended 10-20 system
    'EEG-8': 'C6',
    'EEG-9': 'CP3',
    'EEG-10': 'CP1',
    'EEG-11': 'CPz',  # Often corresponds to T8 in the extended 10-20 system
    'EEG-12': 'CP2',  # Often corresponds to P7 in the extended 10-20 system
    'EEG-13': 'CP4',
    'EEG-14': 'P1',
    'EEG-15': 'P2',
    'EEG-16': 'POz',  # Often corresponds to P8 in the extended 10-20 system
    'EEG-C3': 'C3',  # C3 does not need to be remapped
    'EEG-Cz': 'Cz',  # Cz does not need to be remapped
    'EEG-C4': 'C4',  # C4 does not need to be remapped
    'EEG-Pz': 'Pz',  # Pz does not need to be remapped
    'EEG-Fz': 'Fz',  # Fz does not need to be remapped
}
channel_types_mapping = {
    'FC3':'eeg',
    'FC1':'eeg',
    'FCz':'eeg',
    'FC2':'eeg',
    'FC4':'eeg',
    'C5':'eeg',
    'C1':'eeg',
    'C2':'eeg', 
    'C6':'eeg',
    'CP3':'eeg',
    'CP1':'eeg',
    'CPz':'eeg',  
    'CP2':'eeg',  
    'CP4':'eeg',
    'P1':'eeg',
    'P2':'eeg',
    'POz':'eeg',  
    'C3':'eeg',  
    'Cz':'eeg',  
    'C4':'eeg',  
    'Pz':'eeg',  
    'Fz':'eeg'
}

# The following electrodes have overlapping positions, which causes problems during visualization:
# Fc3, CPZ, TOz, EOG-0, EOG-1, EOG-2
# Apply the renaming
raw_combined.rename_channels(channel_names_mapping)
raw_combined.set_channel_types(mapping=channel_types_mapping)
raw_combined.set_channel_types({
    'EOG-left': 'eog',
    'EOG-central': 'eog',
    'EOG-right': 'eog'
})

montage = mne.channels.make_standard_montage('standard_1020')
raw_combined.set_montage(montage, on_missing='ignore')
raw_combined.plot_sensors(show_names=True)
print()
# Out:
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A02T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A03T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A04T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 600914  =      0.000 ...  2403.656 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A05T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A06T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A07T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A08T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Extracting EDF parameters from c:\Users\PC\Desktop\props\dataset\A09T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# c:\Python311\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)

# %%
processed_epochs = pre_processing.pre_processing(raw_combined,log=False)
# Out:
# Raw Data
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Effective window size : 8.192 (s)
# c:\Python311\Lib\site-packages\mne\viz\utils.py:161: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# Filtered Data
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Effective window size : 8.192 (s)
# c:\Python311\Lib\site-packages\mne\viz\utils.py:161: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNEFigure size 975x967 with 20 Axes>
# <MNEFigure size 390x260.5 with 2 Axes>
# Creating RawArray with float64 data, n_channels=25, n_times=6005911
#     Range : 0 ... 6005910 =      0.000 ... 24023.640 secs
# Ready.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Using EOG channels: EOG-left, EOG-central, EOG-right
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.5s remaining:    0.0s
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.5s remaining:    0.0s
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    3.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.5s remaining:    0.0s
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    3.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ICA
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Effective window size : 8.192 (s)
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# c:\Python311\Lib\site-packages\mne\viz\utils.py:161: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   (fig or plt).show(**kwargs)
# c:\Users\PC\Desktop\props\pre_processing.py:39: FutureWarning: The current default events=None is deprecated and will change to events=True in MNE 1.6. Set events=False to suppress this warning.
#   epochs[1].plot(n_epochs=1, block=True)
# Epochs
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Epochs baseline
# Not setting metadata
# 2592 matching events found
# No baseline correction applied
# 0 projection items activated
# combining channels using "mean"
# Not setting metadata
# 2592 matching events found
# No baseline correction applied
# 0 projection items activated
# combining channels using "mean"
# Rerefrence

# %%
df = processed_epochs.to_data_frame()

# Drop EOG channels and assign the result back to df
# df = df.drop(columns=['EOG-left', 'EOG-central', 'EOG-right'])

# Display a subset of the DataFrame (rows 25 to 30)
df.loc[0:1]
# Out:
#     time condition  epoch        Fz       FC3       FC1       FCz       FC2  \
# 0 -0.100        10      8 -8.668107 -5.232161 -7.279616 -6.215060 -8.881057
# 1 -0.096        10      8 -3.556804 -3.144811 -2.508638 -2.782223 -2.814951
#
#         FC4        C5  ...        C6       CP3       CP1       CPz       CP2  \
# 0 -8.189340 -3.563732  ... -6.888788 -4.043654 -6.965738 -6.394222 -8.862157
# 1 -2.892829 -0.625212  ... -2.672647 -3.684388 -4.088795 -4.929811 -3.351531
#
#          CP4        P1        Pz        P2       POz
# 0 -10.546006 -6.772161 -9.306925 -9.323683 -9.576823
# 1  -5.297656 -5.161789 -6.636275 -6.400223 -7.692719
#
# [2 rows x 25 columns]

# %%
y = processed_epochs.events[:, -1]
X = processed_epochs.get_data()

# %%
import numpy as np

print(np.shape(X))
print(np.shape(y))
# Out:
# (2592, 22, 201)
# (2592,)
